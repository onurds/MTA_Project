# %% [markdown]
# # MTA Direction Auto-Labeler for NER Training
#
# This notebook auto-labels directions in MTA bus and subway alerts using rule-based pattern matching.
#
# ## Label Types:
# - **COMPASS**: NORTHBOUND, SOUTHBOUND, EASTBOUND, WESTBOUND
# - **BOROUGH**: MANHATTAN_BOUND, QUEENS_BOUND, BRONX_BOUND, BROOKLYN_BOUND, STATENISLAND_BOUND
# - **LOCAL**: UPTOWN, DOWNTOWN
# - **PLACE_BOUND**: Any other location-based direction
# - **BOTH_DIRECTIONS**: Both/either direction phrases
# - **UNSPECIFIED**: No direction detected

# %%
import re
import csv
import json
import pandas as pd
from collections import defaultdict

# %% [markdown]
# ## 1. Direction Classifier
#
# Classifies detected direction targets into compass, borough, or place-bound labels.

# %%
class DirectionClassifier:
    """Classifies direction targets according to precedence rules."""
    
    COMPASS_TERMS = {'north', 'south', 'east', 'west'}
    BOROUGH_TERMS = {'manhattan', 'queens', 'bronx', 'brooklyn', 'staten island'}
    LOCAL_TERMS = {'uptown', 'downtown'}
    
    COMPASS_LABELS = {
        'north': 'NORTHBOUND',
        'south': 'SOUTHBOUND',
        'east': 'EASTBOUND',
        'west': 'WESTBOUND'
    }
    
    BOROUGH_LABELS = {
        'manhattan': 'MANHATTAN_BOUND',
        'queens': 'QUEENS_BOUND',
        'bronx': 'BRONX_BOUND',
        'brooklyn': 'BROOKLYN_BOUND',
        'staten island': 'STATENISLAND_BOUND'
    }
    
    LOCAL_LABELS = {
        'uptown': 'UPTOWN',
        'downtown': 'DOWNTOWN'
    }
    
    @classmethod
    def classify(cls, target_text):
        """
        Classify a direction target into COMPASS, BOROUGH, LOCAL, or PLACE_BOUND.
        
        Args:
            target_text: The extracted target string
        
        Returns:
            str: The normalized direction label
        """
        target_normalized = target_text.strip().lower()
        
        # Precedence 1: Check compass directions
        if target_normalized in cls.COMPASS_TERMS:
            return cls.COMPASS_LABELS[target_normalized]
        
        # Precedence 2: Check borough names
        if target_normalized in cls.BOROUGH_TERMS:
            return cls.BOROUGH_LABELS[target_normalized]
        
        # Precedence 3: Check local directions
        if target_normalized in cls.LOCAL_TERMS:
            return cls.LOCAL_LABELS[target_normalized]
        
        # Precedence 4: Everything else is PLACE_BOUND
        return 'PLACE_BOUND'

# %% [markdown]
# ## 2. Direction Detector
#
# Implements pattern matching rules for detecting direction mentions.

# %%
class DirectionDetector:
    """Detects direction mentions in MTA alert headers."""
    
    # Rejection patterns - be very conservative to avoid false rejections
    # Only reject clearly invalid patterns
    REJECTION_PATTERNS = [
        r'\bin\s+both\s+directions?\s+of\b',  # "in both direction of X" (invalid)
        # Note: "Westbound to Manhattan" is VALID - the direction IS "Westbound"
        # Note: "due to", "because of" appearing AFTER direction are OK
    ]
    

    
    def __init__(self):
        """Initialize the detector with compiled patterns."""
        self.classifier = DirectionClassifier()
        
        # Specific patterns for boroughs (highest priority)
        # Allow matching after non-letters (spaces, digits, punctuation, newlines, etc.)
        # Use MULTILINE flag so ^ matches at start of lines (after \n)
        # Use (?:\b|(?=[A-Z0-9])) to match cases like "queensboundQ42"
        self.borough_patterns = [
            (re.compile(r'(?:^|(?<=[^a-zA-Z]))Manhattan[-\s]?bound(?:\b|(?=[A-Z0-9]))', re.IGNORECASE | re.MULTILINE), 'MANHATTAN_BOUND'),
            (re.compile(r'(?:^|(?<=[^a-zA-Z]))Queens[-\s]?bound(?:\b|(?=[A-Z0-9]))', re.IGNORECASE | re.MULTILINE), 'QUEENS_BOUND'),
            (re.compile(r'(?:^|(?<=[^a-zA-Z]))Bronx[-\s]?bound(?:\b|(?=[A-Z0-9]))', re.IGNORECASE | re.MULTILINE), 'BRONX_BOUND'),
            (re.compile(r'(?:^|(?<=[^a-zA-Z]))Brooklyn[-\s]?bound(?:\b|(?=[A-Z0-9]))', re.IGNORECASE | re.MULTILINE), 'BROOKLYN_BOUND'),
            (re.compile(r'(?:^|(?<=[^a-zA-Z]))Staten\s+Island[-\s]?bound(?:\b|(?=[A-Z0-9]))', re.IGNORECASE | re.MULTILINE), 'STATENISLAND_BOUND'),
        ]
        
        # Specific patterns for local directions (Uptown/Downtown)
        self.local_patterns = [
            (re.compile(r'\bUptown\b', re.IGNORECASE), 'UPTOWN'),
            (re.compile(r'\bDowntown\b', re.IGNORECASE), 'DOWNTOWN'),
        ]
        
        # Specific patterns for compass directions
        # Use MULTILINE flag so ^ matches after newlines (e.g., "\nWestbound")
        # Use (?:\b|(?=[A-Z0-9])) instead of \b to match "westboundQ42" (no space before route code)
        self.compass_patterns = [
            (re.compile(r'(?:^|(?<=[^a-zA-Z]))North[-\s]?bound(?:\b|(?=[A-Z0-9]))', re.IGNORECASE | re.MULTILINE), 'NORTHBOUND'),
            (re.compile(r'(?:^|(?<=[^a-zA-Z]))South[-\s]?bound(?:\b|(?=[A-Z0-9]))', re.IGNORECASE | re.MULTILINE), 'SOUTHBOUND'),
            (re.compile(r'(?:^|(?<=[^a-zA-Z]))East[-\s]?bound(?:\b|(?=[A-Z0-9]))', re.IGNORECASE | re.MULTILINE), 'EASTBOUND'),
            (re.compile(r'(?:^|(?<=[^a-zA-Z]))West[-\s]?bound(?:\b|(?=[A-Z0-9]))', re.IGNORECASE | re.MULTILINE), 'WESTBOUND'),
        ]
        
        # Place-bound pattern: captures single word before bound
        # For hyphenated: captures word before hyphen (e.g., "Av-bound" -> "Av")
        # For space: captures single word before space (e.g., "Park bound" -> "Park")
        self.place_bound_pattern = re.compile(
            r'\b([A-Za-z]+)[-\s]bound\b',
            re.IGNORECASE
        )
        
        # R2: Both/either direction(s)
        self.both_either_pattern = re.compile(
            r'\b(?:both|either)\s+directions?\b',
            re.IGNORECASE
        )
    
    def _check_rejection_context(self, text, match_start, match_end):
        """
        Check if match appears in a rejected context.
        
        Only checks BEFORE the match, not after, to avoid false rejections.
        For example, "Westbound buses are detoured due to..." should NOT be rejected
        just because "due to" appears after the direction mention.
        
        Args:
            text: Full header text
            match_start: Start position of match
            match_end: End position of match
            
        Returns:
            bool: True if should reject, False otherwise
        """
        # Only check context BEFORE the match (within the match itself)
        # This catches cases like "bound from X" or "bound to Y" 
        # but not "Westbound buses... due to X" which is valid
        context_start = max(0, match_start - 10)
        context = text[context_start:match_end + 5]  # Small window after for immediate context
        
        for pattern in self.REJECTION_PATTERNS:
            if re.search(pattern, context, re.IGNORECASE):
                return True
        
        return False
    

    def _has_overlap(self, start, end, detected_ranges):
        """Check if range [start, end) overlaps with any detected range."""
        for ds, de in detected_ranges:
            # Check for any overlap
            if not (end <= ds or start >= de):
                return True
        return False
    
    def detect_bound_directions(self, text):
        """
        Detect X-bound / X bound patterns.
        
        Uses priority order: Borough > Local > Compass > Place-bound
        
        Args:
            text: Header text to analyze
            
        Returns:
            list: List of detection dicts
        """
        detections = []
        detected_ranges = []  # Track detected ranges to avoid overlaps
        
        # Priority 1: Check for borough directions
        for pattern, label in self.borough_patterns:
            for match in pattern.finditer(text):
                start_pos = match.start()
                end_pos = match.end()
                
                # Skip if overlaps with already detected
                if self._has_overlap(start_pos, end_pos, detected_ranges):
                    continue
                
                # Check rejection patterns
                if self._check_rejection_context(text, start_pos, end_pos):
                    continue
                
                detected_ranges.append((start_pos, end_pos))
                detections.append({
                    'text': match.group(0),
                    'start': start_pos,
                    'end': end_pos,
                    'label': label
                })
        
        # Priority 2: Check for local directions
        for pattern, label in self.local_patterns:
            for match in pattern.finditer(text):
                start_pos = match.start()
                end_pos = match.end()
                
                # Skip if overlaps with already detected
                if self._has_overlap(start_pos, end_pos, detected_ranges):
                    continue
                
                # Check rejection patterns
                if self._check_rejection_context(text, start_pos, end_pos):
                    continue
                
                detected_ranges.append((start_pos, end_pos))
                detections.append({
                    'text': match.group(0),
                    'start': start_pos,
                    'end': end_pos,
                    'label': label
                })
        
        # Priority 3: Check for compass directions
        for pattern, label in self.compass_patterns:
            for match in pattern.finditer(text):
                start_pos = match.start()
                end_pos = match.end()
                
                # Skip if overlaps with already detected
                if self._has_overlap(start_pos, end_pos, detected_ranges):
                    continue
                
                # Check rejection patterns
                if self._check_rejection_context(text, start_pos, end_pos):
                    continue
                
                detected_ranges.append((start_pos, end_pos))
                detections.append({
                    'text': match.group(0),
                    'start': start_pos,
                    'end': end_pos,
                    'label': label
                })
        
        # Priority 4: Check for place-bound directions
        for match in self.place_bound_pattern.finditer(text):
            start_pos = match.start()
            end_pos = match.end()
            
            # Skip if overlaps with already detected
            if self._has_overlap(start_pos, end_pos, detected_ranges):
                continue
            
            # Check rejection patterns
            if self._check_rejection_context(text, start_pos, end_pos):
                continue
            
            detected_ranges.append((start_pos, end_pos))
            detections.append({
                'text': match.group(0),
                'start': start_pos,
                'end': end_pos,
                'label': 'PLACE_BOUND'
            })
        
        return detections
    
    def detect_both_either(self, text):
        """
        Detect "both/either direction(s)" patterns (R2).
        
        Args:
            text: Header text to analyze
            
        Returns:
            list: List of detection dicts
        """
        detections = []
        
        for match in self.both_either_pattern.finditer(text):
            matched_text = match.group(0)
            
            detections.append({
                'text': matched_text,
                'start': match.start(),
                'end': match.end(),
                'label': 'BOTH_DIRECTIONS'
            })
        
        return detections
    
    def detect_all(self, text):
        """
        Run all detection rules on text.
        
        Args:
            text: Header text to analyze
            
        Returns:
            dict: Detection results
        """
        all_detections = []
        
        # R1: Bound patterns
        bound_detections = self.detect_bound_directions(text)
        all_detections.extend(bound_detections)
        
        # R2: Both/either
        both_either_detections = self.detect_both_either(text)
        all_detections.extend(both_either_detections)
        
        return {'detections': all_detections}

# %% [markdown]
# ## 3. Process Dataset
#
# Load the input data and apply direction detection.

# %% [markdown]
# # Configuration
# INPUT_FILE = 'Preprocessed/MTA_Data_preprocessed.csv'
# OUTPUT_FILE = 'Preprocessed/MTA_Data_silver_directions.csv'
#
# # Initialize detector
# detector = DirectionDetector()

# %%
# Configuration
INPUT_FILE = 'Preprocessed/MTA_Data_preprocessed.csv'
OUTPUT_FILE = 'Preprocessed/MTA_Data_silver_directions.csv'

# Load input data
print(f"Reading {INPUT_FILE}...")
df_input = pd.read_csv(INPUT_FILE)
print(f"Loaded {len(df_input):,} records")

# Initialize detector
detector = DirectionDetector()
# Out:
# Reading Preprocessed/MTA_Data_preprocessed.csv...
# Loaded 230,012 records

# %%
# Process all headers
print("Processing headers...")

# Initialize new columns for the dataframe
direction_spans_list = []
direction_labels_list = []

for idx, row in df_input.iterrows():
    if (idx + 1) % 10000 == 0:
        print(f"  Processed {idx+1:,} / {len(df_input):,} records...")
    
    header_text = row['Header']
    
    # Handle missing or invalid headers (NaN, float, etc.)
    if pd.isna(header_text):
        direction_spans_list.append(json.dumps([]))
        direction_labels_list.append(json.dumps(['UNSPECIFIED']))
        continue
    
    # Convert to string if not already
    header_text = str(header_text)
    
    # Detect directions
    result = detector.detect_all(header_text)
    detections = result['detections']
    
    # Build output
    if detections:
        direction_spans = []
        direction_labels = []
        
        for detection in detections:
            direction_spans.append({
                'text': detection['text'],
                'start': detection['start'],
                'end': detection['end']
            })
            direction_labels.append(detection['label'])
        
        direction_spans_list.append(json.dumps(direction_spans))
        direction_labels_list.append(json.dumps(direction_labels))
    else:
        # No direction detected - label as UNSPECIFIED
        direction_spans_list.append(json.dumps([]))
        direction_labels_list.append(json.dumps(['UNSPECIFIED']))

# Add new columns to the dataframe
df_input['direction_spans'] = direction_spans_list
df_input['direction_labels'] = direction_labels_list

print(f"Completed processing {len(df_input):,} records")
# Out:
# Processing headers...
#   Processed 10,000 / 230,012 records...
#   Processed 20,000 / 230,012 records...
#   Processed 30,000 / 230,012 records...
#   Processed 40,000 / 230,012 records...
#   Processed 50,000 / 230,012 records...
#   Processed 60,000 / 230,012 records...
#   Processed 70,000 / 230,012 records...
#   Processed 80,000 / 230,012 records...
#   Processed 90,000 / 230,012 records...
#   Processed 100,000 / 230,012 records...
#   Processed 110,000 / 230,012 records...
#   Processed 120,000 / 230,012 records...
#   Processed 130,000 / 230,012 records...
#   Processed 140,000 / 230,012 records...
#   Processed 150,000 / 230,012 records...
#   Processed 160,000 / 230,012 records...
#   Processed 170,000 / 230,012 records...
#   Processed 180,000 / 230,012 records...
#   Processed 190,000 / 230,012 records...
#   Processed 200,000 / 230,012 records...
#   Processed 210,000 / 230,012 records...
#   Processed 220,000 / 230,012 records...
#   Processed 230,000 / 230,012 records...
# Completed processing 230,012 records

# %% [markdown]
# ## 4. Generate Statistics
#
# Analyze the detection results and show samples.

# %%
# Generate statistics
stats = {
    'total_records': len(df_input),
    'label_counts': defaultdict(int)
}

samples_by_label = defaultdict(list)

for idx, row in df_input.iterrows():
    labels = json.loads(row['direction_labels'])
    spans = json.loads(row['direction_spans'])
    
    for label in labels:
        stats['label_counts'][label] += 1
        
        # Collect samples (first 10 per label)
        if len(samples_by_label[label]) < 10:
            samples_by_label[label].append({
                'record_id': row['Alert ID'],
                'header': row['Header'],
                'spans': spans
            })

# Print statistics
print("\n" + "="*70)
print("DIRECTION LABELING STATISTICS")
print("="*70)

print(f"\nTotal records processed: {stats['total_records']:,}")

print("\n--- Label Distribution ---")

# Group by type
compass_labels = ['NORTHBOUND', 'SOUTHBOUND', 'EASTBOUND', 'WESTBOUND']
borough_labels = ['MANHATTAN_BOUND', 'QUEENS_BOUND', 'BRONX_BOUND', 'BROOKLYN_BOUND', 'STATENISLAND_BOUND']
local_labels = ['UPTOWN', 'DOWNTOWN']

compass_count = sum(stats['label_counts'][l] for l in compass_labels)
borough_count = sum(stats['label_counts'][l] for l in borough_labels)
local_count = sum(stats['label_counts'][l] for l in local_labels)
place_count = stats['label_counts']['PLACE_BOUND']
both_count = stats['label_counts']['BOTH_DIRECTIONS']
unspecified_count = stats['label_counts']['UNSPECIFIED']

print(f"\nCOMPASS directions: {compass_count:,}")
for label in compass_labels:
    count = stats['label_counts'][label]
    if count > 0:
        print(f"  {label}: {count:,}")

print(f"\nBOROUGH directions: {borough_count:,}")
for label in borough_labels:
    count = stats['label_counts'][label]
    if count > 0:
        print(f"  {label}: {count:,}")

print(f"\nLOCAL directions: {local_count:,}")
for label in local_labels:
    count = stats['label_counts'][label]
    if count > 0:
        print(f"  {label}: {count:,}")

print(f"\nPLACE_BOUND directions: {place_count:,}")
print(f"BOTH_DIRECTIONS: {both_count:,}")
print(f"UNSPECIFIED: {unspecified_count:,}")

print("\n" + "="*70)
print("SAMPLE DETECTIONS (First 5 per label)")
print("="*70)

for label in sorted(samples_by_label.keys()):
    samples = samples_by_label[label][:5]
    print(f"\n{label}:")
    for i, sample in enumerate(samples, 1):
        header_preview = sample['header'][:100] + '...' if len(sample['header']) > 100 else sample['header']
        print(f"  {i}. [{sample['record_id']}] {header_preview}")
        if sample['spans']:
            span_texts = [s['text'] for s in sample['spans']]
            print(f"     Spans: {span_texts}")

# Save statistics to CSV file
stats_output = []
stats_output.append({"Category": "Total Records", "Count": stats["total_records"]})
stats_output.append({"Category": "", "Count": ""})
stats_output.append({"Category": "COMPASS Directions", "Count": compass_count})
for label in compass_labels:
    count = stats["label_counts"][label]
    if count > 0:
        stats_output.append({"Category": f"  {label}", "Count": count})
stats_output.append({"Category": "", "Count": ""})
stats_output.append({"Category": "BOROUGH Directions", "Count": borough_count})
for label in borough_labels:
    count = stats["label_counts"][label]
    if count > 0:
        stats_output.append({"Category": f"  {label}", "Count": count})
stats_output.append({"Category": "", "Count": ""})
stats_output.append({"Category": "LOCAL Directions", "Count": local_count})
for label in local_labels:
    count = stats["label_counts"][label]
    if count > 0:
        stats_output.append({"Category": f"  {label}", "Count": count})
stats_output.append({"Category": "", "Count": ""})
stats_output.append({"Category": "PLACE_BOUND Directions", "Count": place_count})
stats_output.append({"Category": "BOTH_DIRECTIONS", "Count": both_count})
stats_output.append({"Category": "UNSPECIFIED", "Count": unspecified_count})

# Save to CSV
STATS_OUTPUT_FILE = "EDA/direction_labeling_statistics.csv"
df_stats = pd.DataFrame(stats_output)
df_stats.to_csv(STATS_OUTPUT_FILE, index=False)
print(f"\n✓ Statistics saved to {STATS_OUTPUT_FILE}")
# Out:
# ======================================================================
# DIRECTION LABELING STATISTICS
# ======================================================================
#
# Total records processed: 230,012
#
# --- Label Distribution ---
#
# COMPASS directions: 124,806
#   NORTHBOUND: 58,911
#   SOUTHBOUND: 59,521
#   EASTBOUND: 3,010
#   WESTBOUND: 3,364
#
# BOROUGH directions: 6,075
#   MANHATTAN_BOUND: 2,636
#   QUEENS_BOUND: 1,286
#   BRONX_BOUND: 785
#   BROOKLYN_BOUND: 1,217
#   STATENISLAND_BOUND: 151
#
# LOCAL directions: 6,167
#   UPTOWN: 3,071
#   DOWNTOWN: 3,096
#
# PLACE_BOUND directions: 25,531
# BOTH_DIRECTIONS: 43,070
# UNSPECIFIED: 48,331
#
# ======================================================================
# SAMPLE DETECTIONS (First 5 per label)
# ======================================================================
#
# BOTH_DIRECTIONS:
#   1. [189489] L trains are running with delays in both directions after NYPD completed an investigation at 6 Av.
#      Spans: ['both directions']
#   2. [186126] 6 trains are delayed in both directions while we address a mechanical problem on a train at Brooklyn...
#      Spans: ['both directions']
#   3. [184474] M103 buses are no longer detoured in either direction after NYPD investigation at Bowery/Grand St co...
#      Spans: ['either direction']
#   4. [179577] A trains are delayed in both directions while we address a signal problem near 181 St.
#      Spans: ['both directions']
#   5. [170496] 2 trains are delayed in both directions while NYPD investigates someone being disruptive at 225 St.
#      Spans: ['both directions']
#
# BRONX_BOUND:
#   1. [184776] Bronx-bound Q44-SBS and Q50 buses are running with delays because of a crash on the Cross Bronx Expy...
#      Spans: ['Bronx-bound']
#   2. [184797] Bronx-bound Q50 buses are running with delays because of a crash on the Cross Bronx Expy.
#      Spans: ['Bronx-bound']
#   3. [155003] Bronx-bound Bx3 Bx11 Bx13 Bx35 Bx36 buses are detoured because of NYPD activity at University Ave & ...
#      Spans: ['Bronx-bound']
#   4. [155041] Bronx-bound Bx3 Bx11 Bx13 Bx35 Bx36 buses are running with delays after NYPD activity at University ...
#      Spans: ['Bronx-bound']
#   5. [147413] You may wait longer for a Bronx-bound 4 train after someone was being disruptive at Kingston Av.
#      Spans: ['Bronx-bound']
#
# BROOKLYN_BOUND:
#   1. [188004] Brooklyn-bound B D F M N R trains are running with delays after we removed a train with a mechanical...
#      Spans: ['Brooklyn-bound']
#   2. [187889] Brooklyn-bound M R trains are delayed while NYPD responds to a person being disruptive on a train at...
#      Spans: ['Brooklyn-bound']
#   3. [187890] Brooklyn-bound M R trains are running express from Forest Hills-71 Av to Jackson Hts-Roosevelt Av.
# E...
#      Spans: ['Brooklyn-bound']
#   4. [186787] Brooklyn-bound F M trains are running with delays after NYPD responded to people being disruptive on...
#      Spans: ['Brooklyn-bound']
#   5. [186290] Brooklyn-bound F M trains are delayed while we work to correct a door problem on a train at 47-50 St...
#      Spans: ['Brooklyn-bound']
#
# DOWNTOWN:
#   1. [151042] Downtown A trains are delayed while we investigate why a train's brakes activated near Dyckman St.
#      Spans: ['Downtown']
#   2. [144503] Downtown 2 trains are delayed while our crews investigate a switch malfunction at 96 St.
#      Spans: ['Downtown']
#   3. [178673] Southbound 4 5 trains are running at slower speeds while we conduct track and signal maintenance bet...
#      Spans: ['downtown', 'Southbound']
#   4. [169637] Downtown 6 trains are running with delays after we investigated what caused a train's brakes to acti...
#      Spans: ['Downtown']
#   5. [167005] Downtown N R W running with delays between Queens and Manhattan: some southbound N R trains may be r...
#      Spans: ['Downtown', 'southbound']
#
# EASTBOUND:
#   1. [179528] Eastbound B12 buses are no longer detoured following road work on Parkside Ave between Flatbush Ave ...
#      Spans: ['Eastbound']
#   2. [428931] Eastbound Q82 buses are running with delays due to flooding near the UBS Arena.
#      Spans: ['Eastbound']
#   3. [305082] Eastbound M96 buses are no longer detoured after roadwork concluded at 1st Ave/W 97th St.
#      Spans: ['Eastbound']
#   4. [274233] Eastbound M50 buses are no longer detoured following NYPD activity on 50th St from 7th Ave to 5th Av...
#      Spans: ['Eastbound']
#   5. [261583] Eastbound Q19 buses are no longer detoured after roadwork at 21st St/Astoria Blvd concluded.
#      Spans: ['Eastbound']
#
# MANHATTAN_BOUND:
#   1. [145674] Manhattan-bound 2 3 trains are delayed while our crews address a train with a door problem at Grand ...
#      Spans: ['Manhattan-bound']
#   2. [429923] Manhattan-bound Q trains are delayed while NYPD conducts an investigation at Newkirk Plaza.
#      Spans: ['Manhattan-bound']
#   3. [428262] Manhattan-bound 4 trains are delayed while we remove a train from service at Burnside Av.
#      Spans: ['Manhattan-bound']
#   4. [238973] Manhattan-bound M60-SBS buses are delayed because of a crash on the RFK Bridge.
#      Spans: ['Manhattan-bound']
#   5. [188581] Manhattan-bound SIM8, SIM22, SIM23, SIM24, SIM25, SIM26, and SIM30 buses are running with delays bec...
#      Spans: ['Manhattan-bound']
#
# NORTHBOUND:
#   1. [187606] Northbound A trains are delayed while NYPD conducts an investigation at 111 St.
#      Spans: ['Northbound']
#   2. [186517] Northbound F trains are running at slower speeds while we address a signal problem near Bay Pkwy.
#      Spans: ['Northbound']
#   3. [185218] Northbound B D trains are delayed while we address a signal problem near 7 Av.
#      Spans: ['Northbound']
#   4. [185148] Northbound N trains are delayed while we investigate why a train's brakes activated at Bay Pkwy.
#      Spans: ['Northbound']
#   5. [183173] Northbound 2 3 trains are delayed while we remove a train from service at Times Sq-42 St.
#      Spans: ['Northbound']
#
# PLACE_BOUND:
#   1. [189321] Jamaica-bound J trains are delayed while we request EMS assistance for someone at Gates Av.
#      Spans: ['Jamaica-bound']
#   2. [182189] 8 Av-bound L trains are delayed while we investigate a door problem on a train at DeKalb Av.
#      Spans: ['Av-bound']
#   3. [181433] 34 St-Hudson Yards-bound 7 trains are delayed while we work to correct a signal malfunction at 33 St...
#      Spans: ['Yards-bound']
#   4. [158331] Court Sq-bound G trains are delayed while we investigate why a train's brakes activated at Broadway.
#      Spans: ['Sq-bound']
#   5. [157243] Canarsie-Bound L trains are delayed while our crews investigate a mechanical problem on a train at 1...
#      Spans: ['Canarsie-Bound']
#
# QUEENS_BOUND:
#   1. [180084] Queens-bound A trains are running with delays after we removed a train with a mechanical problem fro...
#      Spans: ['Queens-bound']
#   2. [180083] Queens-bound A trains are delayed while we remove a train with a mechanical problem from service at ...
#      Spans: ['Queens-bound']
#   3. [168396] Queens-bound E F M R trains are delayed while we address a signal problem near Jackson Hts-Roosevelt...
#      Spans: ['Queens-bound']
#   4. [166925] Queens-bound A trains are delayed because of debris on the tracks at Utica Av.
#      Spans: ['Queens-bound']
#   5. [166927] Queens-bound A trains are running with delays after debris was removed from the tracks at Utica Av.
#      Spans: ['Queens-bound']
#
# SOUTHBOUND:
#   1. [188948] Southbound Q trains are running with delays after we addressed a door problem at DeKalb Av.
#      Spans: ['Southbound']
#   2. [187749] Southbound B C trains are running with delays after we addressed a door problem on a train at Cathed...
#      Spans: ['Southbound']
#   3. [187618] Southbound 2 3 trains are delayed while we investigate a report of debris on the tracks near 96 St.
#      Spans: ['Southbound']
#   4. [185961] Southbound 2 trains are delayed while we conduct urgent track maintenance at Wall St.
#      Spans: ['Southbound']
#   5. [185847] Southbound N trains are delayed while we remove a train from service at Kings Hwy.
#      Spans: ['Southbound']
#
# STATENISLAND_BOUND:
#   1. [183577] Various Staten Island-bound and Brooklyn express buses are delayed because of a disabled vehicle nea...
#      Spans: ['Staten Island-bound']
#   2. [183579] Various Staten Island-bound and Brooklyn express buses are running with delays after a disabled vehi...
#      Spans: ['Staten Island-bound']
#   3. [183566] Various Staten Island-bound express buses are delayed because of a crash in the Hugh L Carey Tunnel.
#      Spans: ['Staten Island-bound']
#   4. [177867] Staten Island-bound SIM3, SIM6, SIM10 and SIM11 buses are detoured due to an accident at FDR Drive/2...
#      Spans: ['Staten Island-bound']
#   5. [177887] Staten Island-bound SIM7, SIM9, and SIM33 buses are no longer detoured after a movie shoot on Murray...
#      Spans: ['Staten Island-bound']
#
# UNSPECIFIED:
#   1. [180128] A C trains are delayed while we conduct emergency track repairs in Manhattan.
#   2. [185055] All M trains will depart from Track 2.
#   3. [178094] Q20A buses are no longer detoured after road work on 20th Ave between College Point Blvd and 124th S...
#   4. [169356] B1 buses are no longer detoured after an earlier stuck vehicle was moved at 86th St/20th Ave.
#   5. [157671] You may wait longer for a G train. We're running as much service as we can with the train crews we h...
#
# UPTOWN:
#   1. [428882] Uptown 6 trains are delayed while we address a signal problem at 3 Av-138 St.
#      Spans: ['Uptown']
#   2. [425341] Uptown 2/3 trains are delayed while we remove a train from service at Nevins St.
#      Spans: ['Uptown']
#   3. [185739] Uptown F M trains are running with delays while we troubleshoot a signal malfunction near Broadway-L...
#      Spans: ['Uptown']
#   4. [185745] Uptown F M trains are running with delays after we addressed a signal malfunction near Broadway-Lafa...
#      Spans: ['Uptown']
#   5. [181582] Northbound 4 5 trains are delayed while we troubleshoot a signal problem at 125 St.
#
# Some uptown tr...
#      Spans: ['uptown', 'Northbound']
#
# WESTBOUND:
#   1. [183014] Westbound Q39 buses are no longer detoured following road work at 44th Dr/23rd St.
#      Spans: ['Westbound']
#   2. [180606] Westbound B35 buses have resumed making regular stops after an illegally parked vehicle was moved.
#      Spans: ['Westbound']
#   3. [148598] Westbound Q8 buses are no longer detoured after utility work at Liberty Ave/Grant Ave ended.
#      Spans: ['Westbound']
#   4. [146256] Westbound Q49 buses have resumed their regular route following FDNY activity at 92nd St/30th Ave.
#      Spans: ['Westbound']
#   5. [411631] Westbound M42 buses are running with delays after the Falun Dafa march along 42nd St ended.
#      Spans: ['Westbound']
#
# ✓ Statistics saved to EDA/direction_labeling_statistics.csv

# %%
# Analyze single vs multiple directions
print("\n" + "="*70)
print("DIRECTION COUNT ANALYSIS")
print("="*70)

direction_count_stats = defaultdict(int)
direction_count_samples = defaultdict(list)

for idx, row in df_input.iterrows():
    labels = json.loads(row['direction_labels'])
    
    # Count UNSPECIFIED as 0 directions
    if labels == ['UNSPECIFIED']:
        num_directions = 0
    else:
        num_directions = len(labels)
    
    direction_count_stats[num_directions] += 1
    
    # Collect samples (first 5 per count)
    if len(direction_count_samples[num_directions]) < 5:
        direction_count_samples[num_directions].append({
            'record_id': row['Alert ID'],
            'header': row['Header'],
            'num_directions': num_directions,
            'direction_labels': labels
        })

# Print statistics
print(f"\nTotal records: {len(df_input):,}")
print(f"\nDirection count breakdown:")

for count in sorted(direction_count_stats.keys()):
    num_records = direction_count_stats[count]
    percentage = (num_records / len(df_input)) * 100
    direction_word = "direction" if count == 1 else "directions"
    print(f"  {count} {direction_word}: {num_records:,} records ({percentage:.2f}%)")

# Show samples
print("\n" + "="*70)
print("SAMPLE RECORDS BY DIRECTION COUNT")
print("="*70)

for count in sorted(direction_count_samples.keys()):
    samples = direction_count_samples[count]
    direction_word = "Direction" if count == 1 else "Directions"
    print(f"\n{count} {direction_word}:")
    for i, sample in enumerate(samples, 1):
        header_preview = sample['header'][:100] + '...' if len(sample['header']) > 100 else sample['header']
        print(f"  {i}. [{sample['record_id']}] {header_preview}")
        print(f"     Labels: {sample['direction_labels']}")

# Save to CSV
direction_count_output = []
for count in sorted(direction_count_stats.keys()):
    num_records = direction_count_stats[count]
    percentage = (num_records / len(df_input)) * 100
    direction_word = "direction" if count == 1 else "directions"
    direction_count_output.append({
        "Direction_Count": count,
        "Description": f"{count} {direction_word}",
        "Number_of_Records": num_records,
        "Percentage": round(percentage, 2)
    })

# Add summary statistics
zero_direction = direction_count_stats.get(0, 0)
single_direction = direction_count_stats.get(1, 0)
multiple_directions = sum(direction_count_stats.get(k, 0) for k in direction_count_stats.keys() if k > 1)

direction_count_output.append({})
direction_count_output.append({
    "Direction_Count": "Summary",
    "Description": "No direction (UNSPECIFIED)",
    "Number_of_Records": zero_direction,
    "Percentage": round((zero_direction / len(df_input)) * 100, 2)
})
direction_count_output.append({
    "Direction_Count": "Summary",
    "Description": "Single direction",
    "Number_of_Records": single_direction,
    "Percentage": round((single_direction / len(df_input)) * 100, 2)
})
direction_count_output.append({
    "Direction_Count": "Summary",
    "Description": "Multiple directions",
    "Number_of_Records": multiple_directions,
    "Percentage": round((multiple_directions / len(df_input)) * 100, 2)
})

DIRECTION_COUNT_FILE = "EDA/direction_count_analysis.csv"
df_direction_count = pd.DataFrame(direction_count_output)
df_direction_count.to_csv(DIRECTION_COUNT_FILE, index=False)
print(f"\n✓ Direction count analysis saved to {DIRECTION_COUNT_FILE}")
# Out:
# ======================================================================
# DIRECTION COUNT ANALYSIS
# ======================================================================
#
# Total records: 230,012
#
# Direction count breakdown:
#   0 directions: 48,331 records (21.01%)
#   1 direction: 162,882 records (70.81%)
#   2 directions: 15,750 records (6.85%)
#   3 directions: 1,996 records (0.87%)
#   4 directions: 593 records (0.26%)
#   5 directions: 232 records (0.10%)
#   6 directions: 102 records (0.04%)
#   7 directions: 47 records (0.02%)
#   8 directions: 26 records (0.01%)
#   9 directions: 8 records (0.00%)
#   10 directions: 12 records (0.01%)
#   11 directions: 10 records (0.00%)
#   12 directions: 8 records (0.00%)
#   13 directions: 10 records (0.00%)
#   14 directions: 5 records (0.00%)
#
# ======================================================================
# SAMPLE RECORDS BY DIRECTION COUNT
# ======================================================================
#
# 0 Directions:
#   1. [180128] A C trains are delayed while we conduct emergency track repairs in Manhattan.
#      Labels: ['UNSPECIFIED']
#   2. [185055] All M trains will depart from Track 2.
#      Labels: ['UNSPECIFIED']
#   3. [178094] Q20A buses are no longer detoured after road work on 20th Ave between College Point Blvd and 124th S...
#      Labels: ['UNSPECIFIED']
#   4. [169356] B1 buses are no longer detoured after an earlier stuck vehicle was moved at 86th St/20th Ave.
#      Labels: ['UNSPECIFIED']
#   5. [157671] You may wait longer for a G train. We're running as much service as we can with the train crews we h...
#      Labels: ['UNSPECIFIED']
#
# 1 Direction:
#   1. [189489] L trains are running with delays in both directions after NYPD completed an investigation at 6 Av.
#      Labels: ['BOTH_DIRECTIONS']
#   2. [189321] Jamaica-bound J trains are delayed while we request EMS assistance for someone at Gates Av.
#      Labels: ['PLACE_BOUND']
#   3. [188948] Southbound Q trains are running with delays after we addressed a door problem at DeKalb Av.
#      Labels: ['SOUTHBOUND']
#   4. [187749] Southbound B C trains are running with delays after we addressed a door problem on a train at Cathed...
#      Labels: ['SOUTHBOUND']
#   5. [187618] Southbound 2 3 trains are delayed while we investigate a report of debris on the tracks near 96 St.
#      Labels: ['SOUTHBOUND']
#
# 2 Directions:
#   1. [189564] Southbound B D F and Metropolitan-bound M  trains are delayed while we investigate why a train's bra...
#      Labels: ['SOUTHBOUND', 'PLACE_BOUND']
#   2. [189451] Southbound N R W trains are running at slower speeds near 49 St.
#
# Some southbound R trains are being...
#      Labels: ['SOUTHBOUND', 'SOUTHBOUND']
#   3. [189423] Northbound F and 71 Av-bound M trains are running with delays after we addressed a door problem on a...
#      Labels: ['NORTHBOUND', 'PLACE_BOUND']
#   4. [189406] Southbound C trains are running express from Hoyt-Schermerhorn Sts to Broadway Junction.
# C trains ar...
#      Labels: ['SOUTHBOUND', 'BOTH_DIRECTIONS']
#   5. [189393] Broad St-bound J and Forest Hills-bound M trains are running with delays after we removed a train wi...
#      Labels: ['PLACE_BOUND', 'PLACE_BOUND']
#
# 3 Directions:
#   1. [186404] Metropolitan Ave-bound M, World Trade Center-bound E and southbound F trains are running with delays...
#      Labels: ['SOUTHBOUND', 'PLACE_BOUND', 'PLACE_BOUND']
#   2. [184371] Wakefield-241 St-bound 2 trains will arrive/depart on the Flatbush Av-bound platform at 3 Av-149 St....
#      Labels: ['PLACE_BOUND', 'PLACE_BOUND', 'BOTH_DIRECTIONS']
#   3. [178951] Northbound D via A from W 4 to 59 St.
#
# Northbound F via G from Bergen St to Court Sq.
#
# Northbound B ...
#      Labels: ['NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND']
#   4. [168221] Northbound 2 3 express from Franklin Ave to Atlantic Ave.
#
# Some southbound 2 will end at 42nd St or...
#      Labels: ['NORTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND']
#   5. [166476] Southbound X27 and X37 buses are detoured because of unsafe vegetation between Westbound Gowanus Exp...
#      Labels: ['SOUTHBOUND', 'WESTBOUND', 'WESTBOUND']
#
# 4 Directions:
#   1. [425759] Downtown B/D service has resumed.
# Limited uptown B service.
# No Uptown D in Manhattan.
# Uptown D will ...
#      Labels: ['UPTOWN', 'UPTOWN', 'UPTOWN', 'DOWNTOWN']
#   2. [371893] Northbound 4 will arrive on the Brooklyn-bound platform at Bowling Green.
# Southbound 4 will arrive ...
#      Labels: ['BRONX_BOUND', 'BROOKLYN_BOUND', 'NORTHBOUND', 'SOUTHBOUND']
#   3. [285319] B D trains are running with delays in both directions, especially northbound. Northbound F and 57 St...
#      Labels: ['NORTHBOUND', 'NORTHBOUND', 'PLACE_BOUND', 'BOTH_DIRECTIONS']
#   4. [243584] Southbound F and Church Av-bound G running with delays.
#
# Some southbound F and Church Av-bound G exp...
#      Labels: ['SOUTHBOUND', 'SOUTHBOUND', 'PLACE_BOUND', 'PLACE_BOUND']
#   5. [205184] Southbound F and E trains in both directions are running with significant delays.
#
# Middle Village-bo...
#      Labels: ['SOUTHBOUND', 'SOUTHBOUND', 'PLACE_BOUND', 'BOTH_DIRECTIONS']
#
# 5 Directions:
#   1. [108724] N R W service is disrupted between Manhattan and Queens while we investigate a temporary loss of thi...
#      Labels: ['NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND']
#   2. [108728] N R W service is disrupted between Manhattan and Queens while we investigate a temporary loss of thi...
#      Labels: ['NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND']
#   3. [108729] N R W service is disrupted between Manhattan and Queens while we investigate a temporary loss of thi...
#      Labels: ['NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND']
#   4. [108310] Southbound E and F trains are delayed and/or rerouted while emergency teams respond to a person who ...
#      Labels: ['NORTHBOUND', 'NORTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND']
#   5. [108251] Downtown B and C trains are delayed and/or rerouted while we investigate why a B train's brakes were...
#      Labels: ['UPTOWN', 'DOWNTOWN', 'DOWNTOWN', 'PLACE_BOUND', 'PLACE_BOUND']
#
# 6 Directions:
#   1. [108742] N R W service is disrupted between Manhattan and Queens while we investigate a temporary loss of thi...
#      Labels: ['NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'SOUTHBOUND', 'BOTH_DIRECTIONS']
#   2. [107766] E F M R trains are rerouted and experiencing extensive delays in both directions because of a networ...
#      Labels: ['PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'BOTH_DIRECTIONS']
#   3. [107756] E F M R trains are delayed and rerouted in both directions because of a network communications issue...
#      Labels: ['PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'BOTH_DIRECTIONS']
#   4. [106984] 2 3 4 service is suspended in Brooklyn while NYPD conducts an investigation at Atlantic Av-Barclays ...
#      Labels: ['QUEENS_BOUND', 'UPTOWN', 'DOWNTOWN', 'SOUTHBOUND', 'SOUTHBOUND', 'BOTH_DIRECTIONS']
#   5. [106985] 2 3 4 service is suspended in Brooklyn while NYPD conducts an investigation at Atlantic Av-Barclays ...
#      Labels: ['QUEENS_BOUND', 'UPTOWN', 'DOWNTOWN', 'SOUTHBOUND', 'SOUTHBOUND', 'BOTH_DIRECTIONS']
#
# 7 Directions:
#   1. [108307] 4 6 trains are delayed and re-routed in both directions while NYPD and EMS responds to a customer al...
#      Labels: ['NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'BOTH_DIRECTIONS']
#   2. [108309] 4 6 trains are delayed and re-routed in both directions while NYPD and EMS responds to a customer al...
#      Labels: ['NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'BOTH_DIRECTIONS']
#   3. [104243] Broad St-bound J and Forest Hills-71 Av-bound M trains are delayed/rerouted while we investigate a r...
#      Labels: ['PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'BOTH_DIRECTIONS']
#   4. [101564] N W train service is rerouted and partially suspended in both directions while we request medical he...
#      Labels: ['NORTHBOUND', 'NORTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'BOTH_DIRECTIONS', 'BOTH_DIRECTIONS', 'BOTH_DIRECTIONS']
#   5. [101261] A C service is disrupted in both directions while NYPD investigates reports of an unauthorized perso...
#      Labels: ['NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'BOTH_DIRECTIONS', 'BOTH_DIRECTIONS']
#
# 8 Directions:
#   1. [106070] There is no northbound A C service at High St, Fulton St, Chambers St, Canal St and Spring St while ...
#      Labels: ['NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'PLACE_BOUND']
#   2. [105691] There is no northbound service at N Q R stations in Manhattan while NYPD assists an unauthorized per...
#      Labels: ['NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'BOTH_DIRECTIONS']
#   3. [103787] D N R trains are not running between DeKalb Av and 36 St in both directions while emergency teams re...
#      Labels: ['NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'BOTH_DIRECTIONS', 'BOTH_DIRECTIONS']
#   4. [89748] A C trains are delayed/rerouted in both directions while our crews work to correct a switch malfunct...
#      Labels: ['QUEENS_BOUND', 'QUEENS_BOUND', 'QUEENS_BOUND', 'UPTOWN', 'UPTOWN', 'PLACE_BOUND', 'BOTH_DIRECTIONS', 'BOTH_DIRECTIONS']
#   5. [85269] There is no northbound 6 service from Manhattan into the Bronx while we work to fix a signal problem...
#      Labels: ['BRONX_BOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'SOUTHBOUND', 'BOTH_DIRECTIONS']
#
# 9 Directions:
#   1. [108463] 1 2 3 service is disrupted while NYPD assists someone in need of medical help at Times Sq-42 St.
#
# Ex...
#      Labels: ['NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'BOTH_DIRECTIONS', 'BOTH_DIRECTIONS']
#   2. [106611] Southbound C trains are running express from 59 St-Columbus Circle to Canal St while we investigate ...
#      Labels: ['NORTHBOUND', 'NORTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND']
#   3. [103797] Northbound D N R trains are not running between 36 St and DeKalb Av while emergency teams respond to...
#      Labels: ['NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND']
#   4. [70831] There are severe delays and re-routed trains on the E F M R lines between Manhattan and Queens while...
#      Labels: ['PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'BOTH_DIRECTIONS', 'BOTH_DIRECTIONS']
#   5. [52025] A C F service is significantly disrupted while NYPD attempts to apprehend an unauthorized person in ...
#      Labels: ['NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'BOTH_DIRECTIONS']
#
# 10 Directions:
#   1. [108192] Northbound 4 5 service is disrupted while we make urgent track repairs in the tunnel from Brooklyn t...
#      Labels: ['NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND']
#   2. [108196] Northbound 4 5 service is disrupted while we make urgent track repairs in the tunnel from Brooklyn t...
#      Labels: ['NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND']
#   3. [99281] F G service is disrupted in both directions while emergency teams respond to a person who was struck...
#      Labels: ['NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'BOTH_DIRECTIONS', 'BOTH_DIRECTIONS', 'BOTH_DIRECTIONS']
#   4. [99282] F G service is disrupted in both directions while emergency teams respond to a person who was struck...
#      Labels: ['NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'BOTH_DIRECTIONS', 'BOTH_DIRECTIONS', 'BOTH_DIRECTIONS']
#   5. [86800] Southbound F trains are running along the A line from W 4 St-Wash Sq to Jay St-MetroTech while we re...
#      Labels: ['NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'PLACE_BOUND']
#
# 11 Directions:
#   1. [90871] E F M R service is disrupted because of a switch problem near 75 Av. Expect major delays in both dir...
#      Labels: ['NORTHBOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'BOTH_DIRECTIONS']
#   2. [78316] There is no northbound F service at 57 St, Lexington Av/63 St, Roosevelt Island, or 21 St-Queensbrid...
#      Labels: ['NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND']
#   3. [76534] There are delays and multiple impacts to N Q R service while we investigate what activated a train's...
#      Labels: ['NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND']
#   4. [59707] A B C D E F M service is disrupted while NYPD investigates after a person was struck by a train at 4...
#      Labels: ['NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'PLACE_BOUND', 'BOTH_DIRECTIONS']
#   5. [59709] Northbound A C trains have resumed stopping at 42 St-Port Authority Bus Terminal on the express trac...
#      Labels: ['NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'SOUTHBOUND', 'PLACE_BOUND']
#
# 12 Directions:
#   1. [91099] Coney Island-bound F and Metropolitan Av-bound M trains are rerouted between Manhattan and Brooklyn ...
#      Labels: ['BROOKLYN_BOUND', 'NORTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'BOTH_DIRECTIONS']
#   2. [90875] E F M R service is disrupted because of a switch problem near 75 Av. Expect major delays in both dir...
#      Labels: ['NORTHBOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'BOTH_DIRECTIONS', 'BOTH_DIRECTIONS']
#   3. [86801] Southbound F trains are running along the A line from W 4 St-Wash Sq to Jay St-MetroTech while we re...
#      Labels: ['NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'PLACE_BOUND']
#   4. [85389] Manhattan-bound E M R trains are rerouted between Queens and Manhattan because a switch is malfuncti...
#      Labels: ['MANHATTAN_BOUND', 'MANHATTAN_BOUND', 'MANHATTAN_BOUND', 'NORTHBOUND', 'NORTHBOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND']
#   5. [77294] There is no southbound R W service at City Hall, Cortlandt St, Rector St, Whitehall St-South Ferry, ...
#      Labels: ['NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'BOTH_DIRECTIONS']
#
# 13 Directions:
#   1. [76535] There are delays and multiple impacts to N Q R service while we investigate what activated a train's...
#      Labels: ['NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'BOTH_DIRECTIONS']
#   2. [76539] There are delays and multiple impacts to N Q R service while our crews work on a train that's experi...
#      Labels: ['NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'BOTH_DIRECTIONS']
#   3. [32355] We’re investigating an incident in which an uptown A train came into contact with debris on the trac...
#      Labels: ['MANHATTAN_BOUND', 'QUEENS_BOUND', 'BRONX_BOUND', 'UPTOWN', 'UPTOWN', 'DOWNTOWN', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'PLACE_BOUND', 'BOTH_DIRECTIONS']
#   4. [32364] We’re investigating an incident in which an uptown A train came into contact with debris on the trac...
#      Labels: ['MANHATTAN_BOUND', 'QUEENS_BOUND', 'BRONX_BOUND', 'UPTOWN', 'UPTOWN', 'DOWNTOWN', 'NORTHBOUND', 'SOUTHBOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'BOTH_DIRECTIONS', 'BOTH_DIRECTIONS']
#   5. [32366] We’re investigating an incident in which an uptown A train came into contact with debris on the trac...
#      Labels: ['MANHATTAN_BOUND', 'QUEENS_BOUND', 'BRONX_BOUND', 'UPTOWN', 'UPTOWN', 'DOWNTOWN', 'NORTHBOUND', 'SOUTHBOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'PLACE_BOUND', 'BOTH_DIRECTIONS', 'BOTH_DIRECTIONS']
#
# 14 Directions:
#   1. [82693] E F M R train service is delayed and partially suspended in Queens in both directions because of a l...
#      Labels: ['NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'PLACE_BOUND', 'BOTH_DIRECTIONS', 'BOTH_DIRECTIONS', 'BOTH_DIRECTIONS', 'BOTH_DIRECTIONS', 'BOTH_DIRECTIONS', 'BOTH_DIRECTIONS']
#   2. [82701] E F M R train service is suspended in Queens in both directions because of a loss of power to our si...
#      Labels: ['NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'PLACE_BOUND', 'BOTH_DIRECTIONS', 'BOTH_DIRECTIONS', 'BOTH_DIRECTIONS', 'BOTH_DIRECTIONS', 'BOTH_DIRECTIONS', 'BOTH_DIRECTIONS']
#   3. [82708] E F M R train service is suspended in Queens in both directions because of a loss of power to our si...
#      Labels: ['NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'PLACE_BOUND', 'BOTH_DIRECTIONS', 'BOTH_DIRECTIONS', 'BOTH_DIRECTIONS', 'BOTH_DIRECTIONS', 'BOTH_DIRECTIONS', 'BOTH_DIRECTIONS']
#   4. [32352] We’re investigating an incident in which an uptown A train came into contact with debris on the trac...
#      Labels: ['MANHATTAN_BOUND', 'QUEENS_BOUND', 'BRONX_BOUND', 'UPTOWN', 'UPTOWN', 'DOWNTOWN', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'PLACE_BOUND', 'BOTH_DIRECTIONS', 'BOTH_DIRECTIONS']
#   5. [32357] We’re investigating an incident in which an uptown A train came into contact with debris on the trac...
#      Labels: ['MANHATTAN_BOUND', 'QUEENS_BOUND', 'BRONX_BOUND', 'UPTOWN', 'UPTOWN', 'DOWNTOWN', 'NORTHBOUND', 'NORTHBOUND', 'NORTHBOUND', 'SOUTHBOUND', 'SOUTHBOUND', 'PLACE_BOUND', 'BOTH_DIRECTIONS', 'BOTH_DIRECTIONS']
#
# ✓ Direction count analysis saved to EDA/direction_count_analysis.csv

# %% [markdown]
# ## 5. Save Output
#
# Write the labeled data to CSV.

# %%
# Save to CSV
print(f"\nWriting output to {OUTPUT_FILE}...")
df_input.to_csv(OUTPUT_FILE, index=False)
print(f"Successfully wrote {len(df_input):,} records to {OUTPUT_FILE}")

# Display first few rows
print("\nFirst 5 rows of output:")
df_input.head()
# Out:
# Writing output to Preprocessed/MTA_Data_silver_directions.csv...
# Successfully wrote 230,012 records to Preprocessed/MTA_Data_silver_directions.csv
#
# First 5 rows of output:
#    Alert ID                    Date       Agency Status Label    Affected  \
# 0    180128  11/05/2022 05:58:00 PM  NYCT Subway       delays  ["A", "C"]
# 1    189489  12/20/2022 07:09:00 PM  NYCT Subway       delays       ["L"]
# 2    189321  12/20/2022 12:31:00 AM  NYCT Subway       delays       ["J"]
# 3    188948  12/18/2022 06:12:00 AM  NYCT Subway       delays       ["Q"]
# 4    187749  12/12/2022 02:26:00 PM  NYCT Subway       delays  ["B", "C"]
#
#                                               Header  \
# 0  A C trains are delayed while we conduct emerge...
# 1  L trains are running with delays in both direc...
# 2  Jamaica-bound J trains are delayed while we re...
# 3  Southbound Q trains are running with delays af...
# 4  Southbound B C trains are running with delays ...
#
#                                      direction_spans     direction_labels
# 0                                                 []      ["UNSPECIFIED"]
# 1  [{"text": "both directions", "start": 36, "end...  ["BOTH_DIRECTIONS"]
# 2  [{"text": "Jamaica-bound", "start": 0, "end": ...      ["PLACE_BOUND"]
# 3    [{"text": "Southbound", "start": 0, "end": 10}]       ["SOUTHBOUND"]
# 4    [{"text": "Southbound", "start": 0, "end": 10}]       ["SOUTHBOUND"]
